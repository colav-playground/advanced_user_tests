# %%
import pandas as pd
import requests

# %%
j=requests.get('https://zenodo.org/record/7789909/files/udea.json?download=1')

# %%
j.status_code
# Out:
# 200

# %%
len(j.json())
# Out:
# 18181

# %%
j.json()[0]['titles']
# Out:
# [{'title': 'Upgrading of benzofuran to hydrocarbons by hydrodeoxygenation over nickel–molybdenum carbide catalysts supported inside multi-wall carbon nanotubes',
#   'lang': 'en',
#   'source': 'openalex'}]

# %%
pd.DataFrame(j.json())
# Out:
#                             _id  \
# 0      64190f251654767daee7a451
# 1      64190f401654767daee7a457
# 2      64190f451654767daee7a459
# 3      64190f4d1654767daee7a45b
# 4      64190f781654767daee7a467
# ...                         ...
# 18176  6420ce671654767daeeabec5
# 18177  6420ced01654767daeeabf02
# 18178  6420cf041654767daeeabf21
# 18179  6420cf321654767daeeabf3d
# 18180  6420d0751654767daeeabff6
#
#                                                   titles  \
# 0      [{'title': 'Upgrading of benzofuran to hydroca...
# 1      [{'title': 'Curvature Arrhenius plot for estim...
# 2      [{'title': 'Cation<mml:math xmlns:mml="http://...
# 3      [{'title': 'Comparison of bulk basic propertie...
# 4      [{'title': 'Peace and the environment at the c...
# ...                                                  ...
# 18176  [{'title': 'Cirujía y Vaginismo', 'lang': 'es'...
# 18177  [{'title': 'Catálogo de los mapas, planos, cro...
# ...
